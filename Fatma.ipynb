# %%
from keras.preprocessing.image import load_img, array_to_img, img_to_array
from keras.applications.vgg19 import decode_predictions
from keras.applications import VGG19,resnet50;
from keras.layers import Conv2D, Input
import numpy as np
from matplotlib import pyplot as plt
o = VGG19(classes=1000,weights='imagenet',input_tensor=Input(shape=(224,224,3)))
a = load_img("./1.jpg",target_size=(224,224));
b = img_to_array(a);
plt.imshow(b[:,:,2]) ;
c = b.reshape(1,b.shape[0],b.shape[1],b.shape[2]);
d = o.predict(c);
e = decode_predictions(d);
print(e[0][0][1])
# Out:
# tiger

# %% [markdown]
# Proje girilen konumdaki canlının familyasını tahmin ediyor
